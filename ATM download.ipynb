# %%
class Atm:
    def __init__(self):
        
        self.__pin=''
        self.__balance=0
        
        self.menu()
    #def get_pin(self):
        #return self.__pin
    #def set_pin(self,new_pin):
        #self.__pin=new_pin
        #print('pin changed')
    def menu(self):
        #print('1.Enter 1 to create pin\n 2.Enter 2 to deposite\n 3.Enter 3 to withdraw\n 4.Enter 4 to check balance\n 5.Enter 5 to exit\n')    
        user_input=input("Hellow,how would you like to proceed\n 1.Enter 1 to create pin\n 2.Enter 2 to deposite\n 3.Enter 3 to withdraw\n 4.Enter 4 to check balance\n 5.Enter 5 to exit\n\n")
        while(user_input!=1 and user_input!=2 and user_input!=3 and user_input!=4):
            if user_input=="1":
                self.createpin()
                print(' 1.Enter 2 to deposite\n 2.Enter 3 to withdraw\n 3.Enter 4 to check balance\n 4.Enter 5 to exit\n\n')    
                user_input=input()
            elif user_input=="2":
                self.deposite()
                #temp=input("enter your pin")
                if self.temp==self.__pin:
                    print(' 1.Enter 2 to deposite\n 2.Enter 3 to withdraw\n 3.Enter 4 to check balance\n 4.Enter 5 to exit\n\n')    
                    user_input=input()    
            elif user_input=="3":
                self.withdraw()
                if self.temp==self.__pin:
                    print(' 1.Enter 2 to deposite\n 2.Enter 3 to withdraw\n 3.Enter 4 to check balance\n 4.Enter 5 to exit\n\n')    
                    user_input=input()
            elif user_input=="4":
                self.checkbalance()
                if self.temp==self.__pin:
                    print(' 1.Enter 2 to deposite\n 2.Enter 3 to withdraw\n 3.Enter 4 to check balance\n 4.Enter 5 to exit\n\n')    
                    user_input=input()
            else:
                print('bye')
                break
    def createpin(self):
        self.__pin=input("enter pin you wants to create")
        print("pin set successfully")
        
    def deposite(self):
        self.temp=input("enter your pin")
        if self.temp==self.__pin:
            dep_balance=int(input("enter amount"))
            self.__balance=self.__balance+dep_balance
            print("deposite successful")
        else:
            print("invalid pin")
            
            
    def withdraw(self):
        self.temp=input("enter your pin")
        if self.temp==self.__pin:
            with_balance=int(input("enter amount"))
            if with_balance<=self.__balance:
                self.__balance=self.__balance-with_balance
                print("amount withdrawn")
            else:
                print("insufficent balance")
        else:
            print("invalid pin")    
    def checkbalance(self):
        self.temp=input("enter your pin")
        if self.temp==self.__pin:
            print('your balance is:',self.__balance)
        else:
            print("invalid pin")
            
sbi=Atm()
# Out:
# Hellow,how would you like to proceed
#  1.Enter 1 to create pin
#  2.Enter 2 to deposite
#  3.Enter 3 to withdraw
#  4.Enter 4 to check balance
#  5.Enter 5 to exit
#
# 1
# enter pin you wants to create1234
# pin set successfully
#  1.Enter 2 to deposite
#  2.Enter 3 to withdraw
#  3.Enter 4 to check balance
#  4.Enter 5 to exit
#
#
# 2
# enter your pin10000
# invalid pin
# enter your pin1234
# enter amount10000
# deposite successful
#  1.Enter 2 to deposite
#  2.Enter 3 to withdraw
#  3.Enter 4 to check balance
#  4.Enter 5 to exit
#
#
# 3
# enter your pin1234
# enter amount5000
# amount withdrawn
#  1.Enter 2 to deposite
#  2.Enter 3 to withdraw
#  3.Enter 4 to check balance
#  4.Enter 5 to exit
#
#
# 4
# enter your pin1234
# your balance is: 5000
#  1.Enter 2 to deposite
#  2.Enter 3 to withdraw
#  3.Enter 4 to check balance
#  4.Enter 5 to exit
#
#
# 5
# bye
